# %% [markdown]
# <a href="https://colab.research.google.com/github/aprajeeta-99/python_projects/blob/main/Credit_Card_Farud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Loading as Pandas Dataframe

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %% [markdown]
# First 5 rows

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 35737  38240  1.232390  0.122010  0.157352  0.261906  0.158523  0.273022
# 35738  38240  1.114040  0.571203  0.427035  2.442135 -0.020967 -0.501774
# 35739  38241  1.057020  0.007895  0.239256  1.236048  0.032239  0.350868
# 35740  38241 -1.546226  0.693338  1.002815 -1.528992  0.294692 -0.464031
# 35741  38241 -0.231062  0.243033  1.071749 -0.324598 -0.000000       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 35737 -0.143169  0.138664 -0.146805  ... -0.233618 -0.677894  0.052511
# 35738  0.320237 -0.082876 -1.182685  ...  0.028826 -0.032705 -0.056634
# 35739  0.023279  0.137328  0.037981  ... -0.043316 -0.022866 -0.155991
# 35740  0.264880  0.307358  0.022915  ... -0.176713 -0.164637  0.197999
# 35741       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35742 entries, 0 to 35741
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    35742 non-null  int64
#  1   V1      35742 non-null  float64
#  2   V2      35742 non-null  float64
#  3   V3      35742 non-null  float64
#  4   V4      35742 non-null  float64
#  5   V5      35742 non-null  float64
#  6   V6      35741 non-null  float64
#  7   V7      35741 non-null  float64
#  8   V8      35741 non-null  float64
#  9   V9      35741 non-null  float64
#  10  V10     35741 non-null  float64
#  11  V11     35741 non-null  float64
#  12  V12     35741 non-null  float64
#  13  V13     35741 non-null  float64
#  14  V14     35741 non-null  float64
#  15  V15     35741 non-null  float64
#  16  V16     35741 non-null  float64
#  17  V17     35741 non-null  float64
#  18  V18     35741 non-null  float64
#  19  V19     35741 non-null  float64
# ...

# %% [markdown]
# Checking for missing values

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# No missing values

# %% [markdown]
# Distribution of legit transction and fraudlent transaction

# %%
credit_card_data['Class'].value_counts()
# Out:
# 0.0    35638
# 1.0      103
# Name: Class, dtype: int64

# %% [markdown]
# Highly unbalanced dataset

# %% [markdown]
# o label represent legit and 1 label represent fraudlent

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (35638, 31)
# (103, 31)

# %%
legit.Amount.describe()
# Out:
# count    35638.000000
# mean        84.185241
# std        227.223359
# min          0.000000
# 25%          7.000000
# 50%         22.000000
# 75%         76.000000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     103.000000
# mean       90.471165
# std       247.173335
# min         0.000000
# 25%         1.000000
# 50%         3.760000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %% [markdown]
# we notice the difference in mean in both and comparing

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    24007.013890 -0.186593  0.055909   0.752026  0.179227 -0.201556
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.102516 -0.094806  0.021671  0.268769  ...  0.043058 -0.032782
# 1.0   -2.306085 -7.743100  3.867920 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.112858 -0.040645  0.008169  0.135484  0.021354  0.008491  0.003549
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#           Amount
# Class
# 0.0    84.185241
# 1.0    90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# huge difference between means

# %% [markdown]
# Undersampling- builiding a sample dataset containing a similar dis of legit and fradulent transactions
