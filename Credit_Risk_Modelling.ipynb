# %% [markdown]
# <a href="https://colab.research.google.com/github/aprajeeta-99/python_projects/blob/main/Credit_Risk_Modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##DISCLAIMER: This is only to give a storyline behind the actually coding, which seemed more important to me from the point of view of learning what goes behind credit risk modelling.

# %% [markdown]
# --------

# %% [markdown]
# ##OBJECTIVE: To understand what credit risk modelling frameworks consists of.

# %% [markdown]
# ------------

# %% [markdown]
# #Backgroud of the project:

# %% [markdown]
# PD model = logistic regression
#
# LDG model = logistic regression
#
# EAD model = linear regression
#
# These models will help us predict dependent variables.
#
# For the PD model: borrower defaulted or not, the *loan status* will help, so that will be our dependent variable.
#
# For the LGD model, calculate how much of the loan was recovered after the borrower had defaulted, this is the *recovery column*, so that will be our dependent variable.
#
# For the EAD model, total recovered principal column, will be our dependent variable.

# %% [markdown]
# ---------------------------------------------------------------------------------

# %% [markdown]
# Discrete or categorical and Continuous or numeric variables.
#
# A distinctive feature of the PD model is that all of its independent variables have to be categorical. The reason is that it is much easier to present the model in a simplified form and turn it into a scorecard.

# %% [markdown]
# However, some of these discrete variables may have too many categories. In this case, we will combine two or more categories into a new category, ultimately aiming to reduce the total number of variables.

# %% [markdown]
# Only when we've reached a final version of the categories, we will proceed to creating dummies.

# %% [markdown]
# -------------------------

# %% [markdown]
# ##GENERAL PREPROCISING

# %% [markdown]
# 1. Preprocessing fro continuous variables: Turn the strings into timestamps.
#
# 2. Preprocessing fro discrete variables: with the discrete features is to create dummy variables for all of their categories. They take the value of one if the observation belongs to a category and the value of zero if it doesn't.
#
# How dummy variables are being created? PANDAS has a built in function for that called pd.get_dummies(dataframe_name['grade variable'])
#
# Can apply the same for all discrete varibables.
#
#
# 3. Checking for NaN values: dataframe_name.isnull()

# %% [markdown]
# -----

# %% [markdown]
# ## How the PD model will look like?

# %% [markdown]
# OBJECTIVE: To build/develop a PD model to predict which borrowes will default and which won't or classifying good and bad borrowers.
#
# STEPS:
#
# A.Model Development: Data pre-processing and training model preparation
#
# 1.Define what a default is. The default definition results in the loan being classified as a non defaulted or good or defaulted or bad.
#
# 2. Create new dummies for good/bad defaulted/ not defaulted.
#
# 3. Fine classing: methodology to turn continuous variables into categories.
#
#    Weight of evidence: gives us an insight into how useful a given category of an independent variable is in explaining dependent variable.
#
#    Information value: shows us how much information the original independent variable brings with respect to explaining the dependent variable the best.
#
# 4. The model might over/under fit. The most basic solution to overfitting is to split our initial dataset into two training and test splits.
#
# 5. We will find the regression coefficient and their corresponding variables.
#
# 6. We will then test to assess which independent variables contribute to predicting borrower default and which don't. (help of P-value)
#
# B. Model Validation:
#
#  7.Now we will use our model to estimate the probability of default of each observation from the test data.
#
#  8.So now I think it's time to calculate and visualize some metrics that will show us how well our model performs. Accuracy of the model depends on the extent to which the model correctly classifies the good borrowers and the bad borrowers.
#
#  9.  To see the extent to which the model predicts correctly or gets confused - confusion matrix.
#
#  10. Two criteria for model performance of classification models: Gini coefficient was created as a measure of income inequality. More precisely, it was originally used to measure the inequality between rich and poor individuals in an economy. The second criterion Kamangar of Smirnoff shows to one extent, the model separates the actual good borrowers from the actual bad borrowers
#
# C. Creating a scorecard from our PD model.
#
# D. Model monitoring: One of the most convenient and widely accepted ways to compare the two populations is using a specific measure called the Population Stability Index abbreviated. The main goal of the Population Stability Index is to determine whether the new data are too different from the original ones.

# %% [markdown]
# ----

# %% [markdown]
# ##LGD AND EAD Models

# %% [markdown]
# LGD: percentage of exposure that was lost after the borrower defaulted and,
#
# EAD: the amount of the exposure at the moment, the borrower defaulted naturally.
#
# STEPS:
#
# 1.Data pre-processing
#
# 2.Create Dummy variables
#
# 3.Check NaN values
#
# 4.Selecting and estimating the independent and dependent variables. For LGD, the dependent variable will be recovery rate. And for EAD, the dependent variable will be credit conversion factor. As the borrower may only have defaulted on a proportion of the original funded amount.That proportion is going to be our dependent variable for the exposure at default model - called credit conversion factor.
#
# 5. Model developemnt:
#
# Create a logistic regression model to estimate if the recovery rate is zero or greater than zero, then for accounts where the recovery rate is greater than zero, will use a linear regression model to calculate the exact value.
#
# Then we split the data.
#
# And then after splitting and training we can test how well our model performs.
#
# For EAD, a linear regression model will be enough. And then after splitting and training we can test how well our model performs.

# %% [markdown]
# ----

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## EL = PD X LGD X EAD

# %% [markdown]
# Depending on this exposure The bank management can decide to be more aggressive or more conservative when it comes to giving out loans in the future.

# %% [markdown]
# ----
